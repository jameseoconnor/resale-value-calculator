# %%
import pandas as pd
import requests
import time
import random
import sqlite3
import re

from pprint import pprint as pp
from bs4 import BeautifulSoup

# %%
def request_get_html(url):
    html = requests.get(url, auth=('user', 'pass'))
    return html.text


def format_string_result(string):
    result = ' '.join(string.split())
    return result.upper()


def calculate_wait_time(lower_limit, upper_limit):
    return random.uniform(lower_limit, upper_limit)


def get_value_from_html(html, tag_type, class_name, tag_attrib=None, str_replace=None):
    try:
        if tag_attrib is not None:
            value = html.find(tag_type, {"class": class_name})[tag_attrib]
        
        else: 
            value = html.find(tag_type, {"class": class_name}).text
    
    except:
        return "N/A"
    
    if str_replace:
        value = value.replace(str_replace, "")
    
    return format_string_result(value)

# %% [markdown]
# ## Get the latest sold items

# %% [markdown]
# ### Available Categories
# - Jackets & Coats
# - Jeans
# - Pants & Jumpsuits
# - Short
# - Tops
#
#
#
# ### Available Genders/ Groups
# - Women
# - Men
# - Kids
# - Home
# - Pets

# %% [markdown]
# The idea here is (ethically) retrieve data about sold items from the Poshmark ressellers website.
#
# If there are any breaches of user agreements here please get in contact with me!

# %%
# URL Variables
base_url = "https://poshmark.com"
brand = 'lululemon_athletica'
gender = "Women"
category = "Tops"
query_filter = "?availability=sold_out"
page_limit = 1

# %%
df = pd.DataFrame(columns=['item_id', 'date_added', 'gender', 'category', 'name', 'size', 'brand', 'list_price', 'sale_price', 'condition', 'link', 'likes', 'comments'])

for i in range(page_limit):
        
    url = base_url + "/brand/" + brand + "-" + gender + "-" + category + query_filter + "&max_id=" + str(i+1)
    soup = BeautifulSoup(request_get_html(url), 'html.parser')
    

    for html_details in soup.find_all("div", {"class": "card card--small"}):
        #   Get Item Name 
        item_name = get_value_from_html(html_details, "img", "ovf--h", tag_attrib="alt")

        #   Get Item Link
        link = base_url + get_value_from_html(html_details, "a", "tile__title tc--b", tag_attrib="href").lower()
        
        #   Get the property listing ID     
        item_id = get_value_from_html(html_details, "a", "tile__title tc--b", tag_attrib="data-et-prop-listing_id")

        #   Get the date added (need to regex a cloudfront url)
        date_added = get_value_from_html(html_details, "img", "ovf--h", tag_attrib="src")
        
        if date_added == 'N/A':
            date_added = get_value_from_html(html_details, "img", "ovf--h", tag_attrib="data-src")

        date_added = re.search('\d{4}\/\d{2}\/\d{2}', date_added)
        date_added = date_added.group(0)
            
            
         #   Get List Price
        list_price = get_value_from_html(html_details, "span", "p--l--1 tc--lg td--lt", str_replace="$")  
        
        #   Get Sale Price
        sale_price = get_value_from_html(html_details, "span", "p--t--1 fw--bold", str_replace="$")        

        #   Get Condition - Not always known
        condition = get_value_from_html(html_details, "span", "condition-tag all-caps tr--uppercase condition-tag--small")

        #   Get Size - Not always known
        size = get_value_from_html(html_details, "a", "tile__details__pipe__size ellipses", str_replace="Size: ")

        #   Get Brand - Not always known
        brand = get_value_from_html(html_details, "a", "tile__details__pipe__brand ellipses")
        
        #   Get the amount of likes the picture recieved 
        try:
            likes_div = html_details.find('div', {"class": 'social-action-bar tile__social-actions'})
            likes = likes_div.find('span').text
        except:
            likes = 0
            continue
        
        #   Get the amount of comments the picture recieved 
#         try:
#             comments_div = html_details.find('div', {"class": 'sd--fl ai--c jc--sb'})
#             coments = comments_div.find('span').text

#         except:
#             comments = 0
#             continue
        

        #   Add to the dataframe
        df = df.append({
            "item_id": item_id,
            "date_added": date_added,
            "gender": gender,
            "category": category,
            'name': item_name, 
            'size': size, 
            "brand": brand, 
            "list_price": list_price,
            'sale_price': sale_price, 
            'condition': condition,
            'link': link,
            'likes': likes,
            'comments': comments
        }, ignore_index=True)
       
    
#     Wait to pull the next page for a few seconds   
    time.sleep(calculate_wait_time(1, 3))

# %%
df.head(10)
# Out:
#                     item_id  date_added gender category  \
# 0  616475D012D88085513A0D2C  2021/10/11  Women     Tops
# 1  6127ACC82CA9ABC7605ABBDD  2021/08/26  Women     Tops
# 2  617856CFCE1E8771ADB41175  2021/10/26  Women     Tops
# 3  6178968EBCDB2F5490101840  2021/10/26  Women     Tops
# 4  614FD4C21E75A847A40FBE97  2021/09/25  Women     Tops
# 5  612EC4D0941F175F9F37EBA5  2021/08/31  Women     Tops
# 6  61608F482E8E4481E18C00CA  2021/10/08  Women     Tops
# 7  604D5ADE81A36C0135BB151D  2021/03/13  Women     Tops
# 8  61788B72446E590A07B9F554  2021/10/26  Women     Tops
# 9  61494546FF83041673D0D3E7  2021/09/20  Women     Tops
#
#                                                 name size  \
# 0                 LULULEMON SCOOP NECK HEATHERED TEE    4
# 1              LULULEMON SCUBA ZIP UP HOODIE SIZE 10   10
# 2       LULULEMON BLACK “SPIN ME” RACERBACK TANK TOP    8
# 3                     LULULEMON SCUBA HOODIE SIZE 8!    8
# 4                 SLEEVELESS MESH PANEL ATHLETIC TOP    S
# 5        LULULEMON ALIGN TANK IN YELLOW PEAR SIZE 12   12
# 6                        LULULEMON SWIFTLY TOP SHIRT    6
# 7                LULULEMON LONG SLEEVE RUNNING SHIRT    6
# 8                                   LULULEMON HOODIE   12
# 9  LULULEMON SWIFTLY TECH SHORT SLEEVE CREW WINE RED    6
#
#                  brand list_price sale_price condition  \
# 0  LULULEMON ATHLETICA          0         25       N/A
# 1  LULULEMON ATHLETICA        138         13       N/A
# 2  LULULEMON ATHLETICA         58         30       N/A
# 3  LULULEMON ATHLETICA        100         45       N/A
# 4  LULULEMON ATHLETICA         48         20       N/A
# 5  LULULEMON ATHLETICA          0         35       N/A
# 6  LULULEMON ATHLETICA         58         36       N/A
# 7  LULULEMON ATHLETICA         98         23       N/A
# 8  LULULEMON ATHLETICA        118         32       N/A
# 9  LULULEMON ATHLETICA         68         50       N/A
#
#                                                 link likes comments
# 0  https://poshmark.com/listing/lululemon-scoop-n...   NaN      NaN
# 1  https://poshmark.com/listing/lululemon-scuba-z...   NaN      NaN
# 2  https://poshmark.com/listing/lululemon-black-s...   NaN      NaN
# 3  https://poshmark.com/listing/lululemon-scuba-h...   NaN      NaN
# 4  https://poshmark.com/listing/sleeveless-mesh-p...   NaN      NaN
# 5  https://poshmark.com/listing/lululemon-align-t...   NaN      NaN
# 6  https://poshmark.com/listing/lululemon-swiftly...   NaN      NaN
# 7  https://poshmark.com/listing/lululemon-long-sl...   NaN      NaN
# 8  https://poshmark.com/listing/lululemon-hoodie-...   NaN      NaN
# 9  https://poshmark.com/listing/lululemon-swiftly...   NaN      NaN

# %% [markdown]
# ## Create the Database

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn


def select_all_tasks(conn, table_name):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute(f"SELECT * FROM {table_name}")

    print_query_result(cur)
    
def print_query_result(cursor):
    
    rows = cursor.fetchall()

    for row in rows:
        print(row)

# %% [markdown]
# ## 1. Create the Table

# %%
# Create the table if it does not exist
conn = create_connection('db/sold_items.db')
conn.execute('''CREATE TABLE IF NOT EXISTS sold_items_women
         (ID TEXT PRIMARY KEY     NOT NULL,
         gender            TEXT    NOT NULL,
         category          INT     NOT NULL,
         name              CHAR(100),
         list_price        CHAR(10),
         sale_price        CHAR(10),
         condition         CHAR(10),
         link              CHAR(100),
         likes             CHAR(4),
         comments          CHAR(4),
         date_added        CHAR(10))
         ;''')
conn.close()

# %% [markdown]
# ## 2. Insert the data into the database

# %%
conn = create_connection('db/sold_items.db')

for index, row in df.iterrows():
    
    name = row["name"].replace('"', '')
    insertion_query = f'''
        INSERT INTO sold_items_women (ID,gender,category,name,list_price,sale_price,condition,link, date_added)
        VALUES ("{row["item_id"]}", "{gender}", "{category}", "{name}", "{row["list_price"]}", "{row["sale_price"]}", "{row["condition"]}", "{row["link"]}", "{row["date_added"]}")
        '''
    try:
        conn.execute(insertion_query)
    except Exception as e: 
        print(e)
        continue

# Commit the changes
conn.commit()

# Close the connection
conn.close()

# %%
conn = create_connection('db/sold_items.db')
data = select_all_tasks(conn, 'sold_items_women')


"""
Do something with data here 

"""


conn.close()
# Out:
# ('615BB4305462C35EDBB705DF', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 LEOPARD PRINT', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-leopard-print-615bb4305462c35edbb705df', '2021/10/02')
# ('615A4DCE946D3734384DEAF7', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 LEOPARD PRINT', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-leopard-print-615a4dce946d3734384deaf7', '2021/10/02')
# ('6159D220CE5F1C6C90F85CC7', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 LEOPARD PRINT', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-leopard-print-6159d220ce5f1c6c90f85cc7', '2021/10/02')
# ('6162365702C187D8FE247650', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 FOREST GREEN', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-forest-green-6162365702c187d8fe247650', '2021/10/02')
# ('6162F7E20C0C96924A81A52F', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 GREEN', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-green-6162f7e20c0c96924a81a52f', '2021/10/02')
# ('615902FE8AE37C9BC3F1A1A0', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 GREEN', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-green-615902fe8ae37c9bc3f1a1a0', '2021/10/02')
# ('615F8233F5C244FB2ECE0D1D', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 WHITE', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-white-615f8233f5c244fb2ece0d1d', '2021/10/02')
# ('61602D471668C3761459E43A', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 GRAY', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-gray-61602d471668c3761459e43a', '2021/10/02')
# ('615E43CBF5C2441FE014FC7A', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 GRAY', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-gray-615e43cbf5c2441fe014fc7a', '2021/10/02')
# ('615BB480F065FEC94A588899', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 GRAY', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-gray-615bb480f065fec94a588899', '2021/10/02')
# ('61676AEDFADBA4BA7C3882E3', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 LEOPARD PRINT', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-leopard-print-61676aedfadba4ba7c3882e3', '2021/10/02')
# ('61676AC27468D5231F6FEC31', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 LEOPARD PRINT', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-leopard-print-61676ac27468d5231f6fec31', '2021/10/02')
# ('61605E42B9190ED0B5B98A9F', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 LEOPARD PRINT', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-leopard-print-61605e42b9190ed0b5b98a9f', '2021/10/02')
# ('61602D471668C3761459E440', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 LEOPARD PRINT', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-leopard-print-61602d471668c3761459e440', '2021/10/02')
# ('615FCC9C3169B27F88A55C15', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 LEOPARD PRINT', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-leopard-print-615fcc9c3169b27f88a55c15', '2021/10/02')
# ('615F0A418D9BE9306C8BA800', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ PANT 25 LEOPARD PRINT', '86', 'NWT', 'https://poshmark.com/listing/lululemon-align-pant-25-leopard-print-615f0a418d9be9306c8ba800', '2021/10/02')
# ('5E5D53327A817334EA756D69', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON SEAMLESS FLOW CROP LEGGINGS RED SIZE 6', '49', 'N/A', 'https://poshmark.com/listing/lululemon-seamless-flow-crop-leggings-red-size-6-5e5d53327a817334ea756d69', '2020/03/02')
# ('5E5D56692E7C2F6B659AF5B9', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON SEAMLESS FLOW CROP LEGGINGS BURGUNDY 6', '39', 'N/A', 'https://poshmark.com/listing/lululemon-seamless-flow-crop-leggings-burgundy-6-5e5d56692e7c2f6b659af5b9', '2020/03/02')
# ('6175A283BB593722EC608AB2', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON COBALT BLUE BLACK FLORAL ATHLETIC LEGGINGS WORKOUT PANTS SIZE 8', '23', 'N/A', 'https://poshmark.com/listing/lululemon-cobalt-blue-black-floral-athletic-leggings-workout-pants-size-8-6175a283bb593722ec608ab2', '2021/10/24')
# ('615F8361284E990EFA4E5DF7', 'Women', 'Pants_&_Jumpsuits', 'NWT LULULEMON HR ALIGN 25” - BLACK', '90', 'NWT', 'https://poshmark.com/listing/nwt-lululemon-hr-align-25-black-615f8361284e990efa4e5df7', '2021/10/07')
# ('60B46ED98DA5C9759B710FE4', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON WUNDER UNDER LEGGINGS', '40', 'N/A', 'https://poshmark.com/listing/lululemon-wunder-under-leggings-60b46ed98da5c9759b710fe4', '2021/05/30')
# ('617748C788CCE3E8821F0977', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON WUNDER UNDER LEGGINGS BLACK 2 4 PILLED', '15', 'N/A', 'https://poshmark.com/listing/lululemon-wunder-under-leggings-black-2-4-pilled-617748c788cce3e8821f0977', '2021/10/25')
# ('616DE31EA2F48CEDDA8C3FA5', 'Women', 'Pants_&_Jumpsuits', 'NWT LULULEMON 2021 GROOVE PANT FLARE SUPER HIGH RISE LEGGINGS ALL BLACK SIZE 6', '198', 'NWT', 'https://poshmark.com/listing/nwt-lululemon-2021-groove-pant-flare-super-high-rise-leggings-all-black-size-6-616de31ea2f48cedda8c3fa5', '2021/10/18')
# ('606CBD4C67BD9126B18F08EC', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON WUNDER UNDER HI-RISE PANT SIZE 2', '75', 'N/A', 'https://poshmark.com/listing/lululemon-wunder-under-hirise-pant-size-2-606cbd4c67bd9126b18f08ec', '2021/04/06')
# ('614FD27E446E59CA8C795492', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON READY TO CRUSH JOGGER', '67', 'N/A', 'https://poshmark.com/listing/lululemon-ready-to-crush-jogger-614fd27e446e59ca8c795492', '2021/09/25')
# ('613D563E8DA5C9372AE7D584', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON BLACK NULU AND MESH MR YOGA CROP 23”', '74', 'NWT', 'https://poshmark.com/listing/lululemon-black-nulu-and-mesh-mr-yoga-crop-23-613d563e8da5c9372ae7d584', '2021/09/11')
# ('6174394F7EC30C3759E7A25D', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON FAST & FREE CROP II NULUX 19', '71', 'N/A', 'https://poshmark.com/listing/lululemon-fast-free-crop-ii-nulux-19-6174394f7ec30c3759e7a25d', '2021/10/23')
# ('6177736EBCDB2F35D80A59F6', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN™ HIGH-RISE PANT 25', '44', 'N/A', 'https://poshmark.com/listing/lululemon-align-highrise-pant-25-6177736ebcdb2f35d80a59f6', '2021/10/25')
# ('61758DE1275E55E7366036F7', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON RUN TOP SPEED CROP LEGGINGS SCRATCH', '38', 'N/A', 'https://poshmark.com/listing/lululemon-run-top-speed-crop-leggings-scratch-61758de1275e55e7366036f7', '2021/10/24')
# ('612FE2E902C1874B3AFD9BDA', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON GRAY SOOT LIGHT WILL CROP LEGGINGS 4', '36', 'N/A', 'https://poshmark.com/listing/lululemon-gray-soot-light-will-crop-leggings-4-612fe2e902c1874b3afd9bda', '2021/09/01')
# ('615121AB941F179E3DF7E71C', 'Women', 'Pants_&_Jumpsuits', '🍋 LULULEMON INVIGORATE 25” LEGGING RASPBERRY 14', '51', 'N/A', 'https://poshmark.com/listing/lululemon-invigorate-25-legging-raspberry-14-615121ab941f179e3df7e71c', '2021/09/26')
# ('60F9D62AC32EE63656223D0B', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON PANTS REVERSIBLE YOGA TAPERED 6 TALL', '37', 'N/A', 'https://poshmark.com/listing/lululemon-pants-reversible-yoga-tapered-6-tall-60f9d62ac32ee63656223d0b', '2021/07/22')
# ('617878B0AC970246FAE579B6', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN LEGGINGS', '30', 'N/A', 'https://poshmark.com/listing/lululemon-align-leggings-617878b0ac970246fae579b6', '2021/10/26')
# ('6178747388CCE3A7CB2529F2', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN HIGH RISE CROP 21”', '40', 'N/A', 'https://poshmark.com/listing/lululemon-align-high-rise-crop-21-6178747388cce3a7cb2529f2', '2021/10/26')
# ('616DC423B51256A8A1F3610C', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON KEEP MOVING PANT 7/8 HIGH-RISE INCOGNITO CAMO MULTI GREY SIZE 8', '45', 'N/A', 'https://poshmark.com/listing/lululemon-keep-moving-pant-78-highrise-incognito-camo-multi-grey-size-8-616dc423b51256a8a1f3610c', '2021/10/18')
# ('615DBBEF81A36C3E3C49205A', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN CAMO 7/8 LENGTH', '70', 'N/A', 'https://poshmark.com/listing/lululemon-align-camo-78-length-615dbbef81a36c3e3c49205a', '2021/10/06')
# ('6164B552633CFC780A92FD45', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON PRINTED CROPPED ATHLETIC PANT', '48', 'N/A', 'https://poshmark.com/listing/lululemon-printed-cropped-athletic-pant-6164b552633cfc780a92fd45', '2021/10/11')
# ('6123EF16D737FD28A617D098', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON IN THE FLOW CROP VERY GREEN', '40', 'N/A', 'https://poshmark.com/listing/lululemon-in-the-flow-crop-very-green-6123ef16d737fd28a617d098', '2021/08/23')
# ('616CB3F31801364E1EF03648', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON GRAPHITE GREY ON THE FLY PANTS/CROP 27IN INSEAM SZ 10', '48', 'N/A', 'https://poshmark.com/listing/lululemon-graphite-grey-on-the-fly-pantscrop-27in-inseam-sz-10-616cb3f31801364e1ef03648', '2021/10/17')
# ('6108C810463D4F5F55C5C400', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ASTRO YOGA PANTS SIZE 2', '28', 'N/A', 'https://poshmark.com/listing/lululemon-astro-yoga-pants-size-2-6108c810463d4f5f55c5c400', '2021/08/02')
# ('6133D86B275E556E0FC4AC49', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON DARK RED SET', '95', 'N/A', 'https://poshmark.com/listing/lululemon-dark-red-set-6133d86b275e556e0fc4ac49', '2021/09/04')
# ('60B16F17C936AF91493A4BD5', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON BLACK CAPRI LENGTH WOMENS LEGGINGS SZ 4', '9', 'N/A', 'https://poshmark.com/listing/lululemon-black-capri-length-womens-leggings-sz-4-60b16f17c936af91493a4bd5', '2021/05/28')
# ('6157285B8DA5C9717B3869F8', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON CAPRI LEGGINGS', '15', 'N/A', 'https://poshmark.com/listing/lululemon-capri-leggings-6157285b8da5c9717b3869f8', '2021/10/01')
# ('61756AE2284E994382C088F5', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON READY TO RULU JOGGER 29 BLACK SIZE 6 HIGH WAIST PANTS', '50', 'N/A', 'https://poshmark.com/listing/lululemon-ready-to-rulu-jogger-29-black-size-6-high-waist-pants-61756ae2284e994382c088f5', '2021/10/24')
# ('61660350284E99D266F9566A', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON ALIGN LEGGING 25”', '50', 'N/A', 'https://poshmark.com/listing/lululemon-align-legging-25-61660350284e99d266f9566a', '2021/10/12')
# ('61786F2BD737FD3C3B8BFA99', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON JOGGERS', '45', 'N/A', 'https://poshmark.com/listing/lululemon-joggers-61786f2bd737fd3c3b8bfa99', '2021/10/26')
# ('6101793D18013607BAF3FF8A', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON | WUNDER UNDER III LUXTREME SHATTER PANT', '59', 'N/A', 'https://poshmark.com/listing/lululemon-wunder-under-iii-luxtreme-shatter-pant-6101793d18013607baf3ff8a', '2021/07/28')
# ('61786DA6633CFC039C90304E', 'Women', 'Pants_&_Jumpsuits', 'LULULEMON LEGGINGS', '40', 'N/A', 'https://poshmark.com/listing/lululemon-leggings-61786da6633cfc039c90304e', '2021/10/26')

# %%
conn = create_connection('db/sold_items.db')
cur = conn.cursor()
cur.execute('''Select count(1) from sold_items_women where cast(sale_price as int)''')
print_query_result(cur)
# Out:
# (480,)

# %% [markdown]
# - User inputs
#     - Brand
#     - Size
#     - Type
#
#
# - This is going to be used to estimate the resale price
#
# What we need to do is take this input, retrieve the data from the database, and calculate average sale value for
#     - This particular size
#     - Other sizes
#     - What they normally list for versus what they sell for
